# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

import pydot
from sklearn.tree import export_graphviz
import graphviz
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns

sns.set(context='notebook', style='darkgrid', palette='colorblind', font='sans-serif', font_scale=1, rc=None)

# %%
data = pd.read_csv('C:/Users/lordo/Downloads/Symptoms and COVID Presence.csv')

# %%
data = data.dropna()

# %%
data.dtypes
# Out:
# Breathing_Problem                          bool
# Fever                                      bool
# Dry_Cough                                  bool
# Sore_throat                                bool
# Running_Nose                               bool
# Asthma                                     bool
# Chronic_Lung_Disease                       bool
# Headache                                   bool
# Heart_Disease                              bool
# Diabetes                                   bool
# Hyper_Tension                              bool
# Fatigue                                    bool
# Gastrointestinal                           bool
# Abroad_travel                              bool
# Contact_with_COVID_Patient                 bool
# Attended_Large_Gathering                   bool
# Visited_Public_Exposed_Places              bool
# Family_working_in_Public_Exposed_Places    bool
# Wearing_Masks                              bool
# Sanitization_from_Market                   bool
# COVID_19                                   bool
# dtype: object

# %%
data.describe()
# Out:
#        Breathing_Problem Fever Dry_Cough Sore_throat Running_Nose Asthma  \
# count               5434  5434      5434        5434         5434   5434
# unique                 2     2         2           2            2      2
# top                 True  True      True        True         True  False
# freq                3620  4273      4307        3953         2952   2920
#
#        Chronic_Lung_Disease Headache Heart_Disease Diabetes  ... Fatigue  \
# count                  5434     5434          5434     5434  ...    5434
# unique                    2        2             2        2  ...       2
# top                   False     True         False    False  ...    True
# freq                   2869     2736          2911     2846  ...    2821
#
#        Gastrointestinal Abroad_travel Contact_with_COVID_Patient  \
# count              5434          5434                       5434
# unique                2             2                          2
# top               False         False                       True
# freq               2883          2983                       2726
#
#        Attended_Large_Gathering Visited_Public_Exposed_Places  \
# count                      5434                          5434
# unique                        2                             2
# top                       False                          True
# freq                       2924                          2820
#
#        Family_working_in_Public_Exposed_Places Wearing_Masks  \
# count                                     5434          5434
# unique                                       2             1
# top                                      False         False
# freq                                      3172          5434
#
#        Sanitization_from_Market COVID_19
# count                      5434     5434
# unique                        1        2
# top                       False     True
# freq                       5434     4383
#
# [4 rows x 21 columns]

# %%
# logic={"Yes":True,"No":False}

# data["Breathing Problem"]=data["Breathing Problem"].map(logic)
# data["Fever"]=data["Fever"].map(logic)
# data["Dry Cough"]=data["Dry Cough"].map(logic)
# data["Sore throat"]=data["Sore throat"].map(logic)
# data["Running Nose"]=data["Running Nose"].map(logic)
# data["Asthma"]=data["Asthma"].map(logic)
# data["Chronic Lung Disease"]=data["Chronic Lung Disease"].map(logic)
# data["Headache"]=data["Headache"].map(logic)
# data["Heart Disease"]=data["Heart Disease"].map(logic)
# data["Diabetes"]=data["Diabetes"].map(logic)
# data["Hyper Tension "]=data["Hyper Tension "].map(logic)
# data["Fatigue"]=data["Fatigue"].map(logic)
# data["Gastrointestinal"]=data["Gastrointestinal"].map(logic)
# data["Abroad travel"]=data["Abroad travel"].map(logic)
# data["Contact with COVID Patient"]=data["Contact with COVID Patient"].map(logic)
# data["Attended Large Gathering"]=data["Attended Large Gathering"].map(logic)
# data["Visited Public Exposed Places"]=data["Visited Public Exposed Places"].map(logic)
# data["Family working in Public Exposed Places"]=data["Family working in Public Exposed Places"].map(logic)
# data["Wearing Masks"]=data["Wearing Masks"].map(logic)
# data["Sanitization from Market"]=data["Sanitization from Market"].map(logic)
# data["COVID-19"]=data["COVID-19"].map(logic)

# %%
data
# Out:
#       Breathing_Problem  Fever  Dry_Cough  Sore_throat  Running_Nose  Asthma  \
# 0                  True   True       True         True          True   False
# 1                  True   True       True         True         False    True
# 2                  True   True       True         True          True    True
# 3                  True   True       True        False         False    True
# 4                  True   True       True         True          True   False
# ...                 ...    ...        ...          ...           ...     ...
# 5429               True   True      False         True          True    True
# 5430               True   True       True        False          True    True
# 5431               True   True       True        False         False   False
# 5432               True   True       True        False          True   False
# 5433               True   True       True        False          True    True
#
#       Chronic_Lung_Disease  Headache  Heart_Disease  Diabetes  ...  Fatigue  \
# 0                    False     False          False      True  ...     True
# 1                     True      True          False     False  ...     True
# 2                     True      True          False      True  ...     True
# 3                    False     False           True      True  ...    False
# 4                     True      True           True      True  ...    False
# ...                    ...       ...            ...       ...  ...      ...
# 5429                  True     False          False     False  ...     True
# 5430                 False      True          False      True  ...     True
# 5431                 False     False           True     False  ...    False
# 5432                 False      True           True     False  ...    False
# 5433                 False      True          False      True  ...     True
#
#       Gastrointestinal  Abroad_travel  Contact_with_COVID_Patient  \
# 0                 True          False                        True
# 1                False          False                       False
# 2                 True           True                       False
# 3                False           True                       False
# 4                 True          False                        True
# ...                ...            ...                         ...
# 5429              True          False                       False
# 5430             False          False                       False
# 5431             False          False                       False
# 5432             False          False                       False
# 5433             False          False                       False
#
#       Attended_Large_Gathering  Visited_Public_Exposed_Places  \
# 0                        False                           True
# 1                         True                           True
# 2                        False                          False
# 3                         True                           True
# 4                        False                           True
# ...                        ...                            ...
# 5429                     False                          False
# 5430                     False                          False
# 5431                     False                          False
# 5432                     False                          False
# 5433                     False                          False
#
#       Family_working_in_Public_Exposed_Places  Wearing_Masks  \
# 0                                        True          False
# 1                                       False          False
# 2                                       False          False
# 3                                       False          False
# 4                                       False          False
# ...                                       ...            ...
# 5429                                    False          False
# 5430                                    False          False
# 5431                                    False          False
# 5432                                    False          False
# 5433                                    False          False
#
#       Sanitization_from_Market  COVID_19
# 0                        False      True
# 1                        False      True
# 2                        False      True
# 3                        False      True
# 4                        False      True
# ...                        ...       ...
# 5429                     False      True
# 5430                     False      True
# 5431                     False     False
# 5432                     False     False
# 5433                     False     False
#
# [5434 rows x 21 columns]

# %%
predictors = data[[
    'Breathing_Problem','Fever','Dry_Cough','Sore_throat','Running_Nose','Asthma','Chronic_Lung_Disease','Headache',
    'Heart_Disease','Diabetes','Hyper_Tension','Fatigue','Gastrointestinal','Abroad_travel','Contact_with_COVID_Patient',
    'Attended_Large_Gathering','Visited_Public_Exposed_Places','Family_working_in_Public_Exposed_Places','Wearing_Masks',
    'Sanitization_from_Market'
]]
targets = data.COVID_19
predictors
# Out:
#       Breathing_Problem  Fever  Dry_Cough  Sore_throat  Running_Nose  Asthma  \
# 0                  True   True       True         True          True   False
# 1                  True   True       True         True         False    True
# 2                  True   True       True         True          True    True
# 3                  True   True       True        False         False    True
# 4                  True   True       True         True          True   False
# ...                 ...    ...        ...          ...           ...     ...
# 5429               True   True      False         True          True    True
# 5430               True   True       True        False          True    True
# 5431               True   True       True        False         False   False
# 5432               True   True       True        False          True   False
# 5433               True   True       True        False          True    True
#
#       Chronic_Lung_Disease  Headache  Heart_Disease  Diabetes  Hyper_Tension  \
# 0                    False     False          False      True           True
# 1                     True      True          False     False          False
# 2                     True      True          False      True          False
# 3                    False     False           True      True          False
# 4                     True      True           True      True           True
# ...                    ...       ...            ...       ...            ...
# 5429                  True     False          False     False          False
# 5430                 False      True          False      True           True
# 5431                 False     False           True     False           True
# 5432                 False      True           True     False          False
# 5433                 False      True          False      True           True
#
#       Fatigue  Gastrointestinal  Abroad_travel  Contact_with_COVID_Patient  \
# 0        True              True          False                        True
# 1        True             False          False                       False
# 2        True              True           True                       False
# 3       False             False           True                       False
# 4       False              True          False                        True
# ...       ...               ...            ...                         ...
# 5429     True              True          False                       False
# 5430     True             False          False                       False
# 5431    False             False          False                       False
# 5432    False             False          False                       False
# 5433     True             False          False                       False
#
#       Attended_Large_Gathering  Visited_Public_Exposed_Places  \
# 0                        False                           True
# 1                         True                           True
# 2                        False                          False
# 3                         True                           True
# 4                        False                           True
# ...                        ...                            ...
# 5429                     False                          False
# 5430                     False                          False
# 5431                     False                          False
# 5432                     False                          False
# 5433                     False                          False
#
#       Family_working_in_Public_Exposed_Places  Wearing_Masks  \
# 0                                        True          False
# 1                                       False          False
# 2                                       False          False
# 3                                       False          False
# 4                                       False          False
# ...                                       ...            ...
# 5429                                    False          False
# 5430                                    False          False
# 5431                                    False          False
# 5432                                    False          False
# 5433                                    False          False
#
#       Sanitization_from_Market
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 5429                     False
# 5430                     False
# 5431                     False
# 5432                     False
# 5433                     False
#
# [5434 rows x 20 columns]

# %%
predictors_labels = ['Breathing_Problem','Fever','Dry_Cough','Sore_throat','Running_Nose','Asthma','Chronic_Lung_Disease','Headache',
    'Heart_Disease','Diabetes','Hyper_Tension','Fatigue','Gastrointestinal','Abroad_travel','Contact_with_COVID_Patient',
    'Attended_Large_Gathering','Visited_Public_Exposed_Places','Family_working_in_Public_Exposed_Places','Wearing_Masks',
    'Sanitization_from_Market']
target_labels = ['True','False']

# %%
X_entrenamiento, X_test, y_entrenamiento, y_test = train_test_split(predictors,targets)

# %%
arbol = DecisionTreeClassifier()
arbol.fit(X_entrenamiento, y_entrenamiento)
# Out:
# DecisionTreeClassifier()

# %%
arbol.score(X_test,y_test)
# Out:
# 0.986019131714496

# %%
arbol.score(X_entrenamiento,y_entrenamiento)
# Out:
# 0.9815950920245399

# %%
export_graphviz(arbol, out_file='arbol.dot', 
                class_names=target_labels,
                feature_names=predictors_labels,
                impurity=True, filled=True
               )
with open('arbol.dot') as f:
    dot_graph=f.read()
graphviz.Source(dot_graph)

# %%
# Descomentar si se desea generar un archivo png con el arbol para mejor visualizacion
(graph,)= pydot.graph_from_dot_file('arbol.dot')
graph.write_png('arbol.png')

# %%
caract = data.shape[1]-1
plt.barh(range(caract),arbol.feature_importances_)
plt.yticks(np.arange(caract),predictors_labels)
plt.xlabel('Importancia de las caracteristicas')
plt.ylabel('Caracteristica')
plt.show()

# %%
arbol.predict([[False,False,False,True,True,True,True,True,True,True,True,True,True,False,True,False,True,True,True,True,]])
# Out:
# array([ True])

# %%
sns.countplot(x='Breathing_Problem',hue='COVID_19',data=data);

# %%
sns.countplot(x='Sore_throat',hue='COVID_19',data=data);

# %%
sns.countplot(x='Abroad_travel',hue='COVID_19',data=data);

# %%
sns.countplot(x='Dry_Cough',hue='COVID_19',data=data);
